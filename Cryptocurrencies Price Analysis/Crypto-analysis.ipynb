# %% [markdown]
# # Cryptocurrencies Price Analysis

# %%
import pandas as pd
import matplotlib.pyplot as plt
plt.style.use('ggplot')
# %matplotlib inline

# %%
df = pd.read_csv('./data/prices-all.csv', index_col='Date')
df.head()
# Out:
#                 Close Price Symbol
# Date
# 7/18/2010 0:00         0.09    BTC
# 7/19/2010 0:00         0.08    BTC
# 7/20/2010 0:00         0.07    BTC
# 7/21/2010 0:00         0.08    BTC
# 7/22/2010 0:00         0.05    BTC

# %%
btc = df[df['Symbol'] == 'BTC']
eth = df[df['Symbol'] == 'ETH']

# %%
fig, (ax0, ax1) = plt.subplots(nrows=1, ncols=2, figsize=(20, 10));
ax0.set(title='BTC')
ax1.set(title='ETH')
btc.plot(subplots=True, ax=ax0)
eth.plot(subplots=True, ax=ax1)
fig.autofmt_xdate()

# %%
fig, (ax0, ax1) = plt.subplots(nrows=1, ncols=2, figsize=(20, 10));
ax0.set(title='Daily BTC Price Changes')
ax1.set(title='Daily BTC Price Changes Histogram')
btc['Close Price'].pct_change().plot(ax=ax0)
btc['Close Price'].pct_change().hist(ax=ax1,bins=100)
fig.autofmt_xdate()

# %%
fig, (ax0, ax1) = plt.subplots(nrows=1, ncols=2, figsize=(20, 10));
ax0.set(title='Daily ETH Price Changes')
ax1.set(title='Daily ETH Price Changes Histogram')
eth['Close Price'].pct_change().plot(ax=ax0)
eth['Close Price'].pct_change().hist(ax=ax1,bins=100)
fig.autofmt_xdate()
